# %% [markdown]
# # Store 1115 Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pd.read_csv('../../../train.csv', low_memory=False)
train_df['Date'] = pd.to_datetime(train_df['Date'])
store_data = train_df[train_df['Store'] == 1115].copy()
store_data.sort_values('Date', inplace=True)

# %%
store_data.describe()

# %%
store_data.plot(x='Date', y='Sales', figsize=(10,4), title='Sales over Time')
plt.show()
