# %% [markdown]
# # Aggregate Summary Across All Stores

# %%
import pandas as pd
summary_df = pd.read_csv('top_level_summary.csv')
summary_df.head()
# Out:
#    Store   Mean_Sales  Missing_Sales Data_Quality
# 0   1115  5225.296178              0         Good
# 1    379  3247.708068              0         Good
# 2    378  5230.382166              0         Good
# 3    377  6507.139066              0         Good
# 4    376  6951.308917              0         Good

# %%
summary_df['Data_Quality'].value_counts().plot(kind='bar', title='Data Quality across Stores')
# Out:
# <Axes: title={'center': 'Data Quality across Stores'}, xlabel='Data_Quality'>
